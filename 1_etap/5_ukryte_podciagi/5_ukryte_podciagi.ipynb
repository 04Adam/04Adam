# %% [markdown]
# # Ukryte Podciągi
# ![](https://live.staticflickr.com/65535/54327633282_6bc45ba42a_o.png)
#
# *Obraz wygenerowany przy użyciu modelu DALL-E.*
#
# ## Wstęp
# Od starożytnych wróżbitów interpretujących układ gwiazd po współczesnych kryptografów tropiących ślady ukrytych wiadomości, ludzkość od zawsze poszukiwała sensu w pozornie chaotycznych danych. Czasem kluczowe informacje ukrywają się w drobnych sekwencjach symboli, a ich wartość ujawnia się dopiero po precyzyjnej analizie.
#
# W tym zadaniu wcielisz się w rolę detektywa, poszukującego strukturalnych zależności w zbiorze binarnych ciągów. Będziesz dysponował zbiorem danych zawierającym przykładowe ciągi oraz ich poprawnie obliczone wartości. Twoim celem będzie opracowanie metody analizy ukrytych wzorców pozwalającej na możliwie najprecyzyjniejsze wyznaczanie wartości ciągów niewystępujących w zbiorze.
#
# Mówimy, że ciąg $T$ jest podciągiem $S$ i oznaczamy $T \subseteq S$ jeżeli
# $$
# T = S_{i_1}S_{i_2} \dots S_{i_k}
# $$
# Gdzie
# $$
# 1 \leq i_1 < i_2 < \dots < i_k \leq n
# $$
# Dla $k$ i $n$ będących długościami ciągów $T$ i $S$ odpowiednio, oraz indeksów ($i_1 < i_2 < \dots < i_k$) będących ściśle rosnącym ciągiem liczb naturalnych (niekoniecznie kolejnych).
#
# Rozwiązaniem dla danego ciągu binarnego $S \in \{0,1\}^{n}$ oraz zdefiniowanego zbioru zawierającego kolejno wzorzec i jego wagę $W = \{(T, v):T \in \{0,1\}^{k}, k \le n, v \in Z\}$ jest liczba
# $$
# \phi(S) = \sum_{(T_{i}, v_{i}) \in W} v_{i} \cdot \text{I} (T_{i})
# $$
# gdzie $\text{I}(T_{i}) = \begin{cases}
# 1, & T_{i} \subseteq S \\
# 0, & T_{i} \subsetneq S
# \end{cases}$
#
# Innymi słowy, $\phi(S)$ jest sumą wartości wszystkich ciągów ze zbioru $W$, które są podciągami $S$.
#
# **Przykład:**
# Dla zbioru $W = \{(1111, 1), (1010, 2)\}$, mamy:
# - $\phi$(0**1111**000) = 1
# - $\phi$(1**10**00**1**0**0**) = 2
# - $\phi$(0**110110**0) = 3,  ponieważ
#
#   - 1111 $\subseteq$ 0**11**0**11**00
#
#   - 1010 $\subseteq$ 01**101**1**0**0
# - $\phi$(01100000) = 0, ponieważ 1111, 1010 $\subsetneq$ 01100000.

# %% [markdown]
# ## Zadanie
# Stwórz model (obiekt typu `nn.Module`) który będzie znajdował wartość $\phi$ dla ciągów ze zbioru danych. Dane treningowe składają się z ciągów $S$ oraz odpowiadających im wartości $\phi(S)$. Zauważ więc, że wzorzec $W$ jest ukryty, a Twoim zadaniem jest przybliżyć $\phi$ bez wiedzy o nim.
#
# Twój model musi przyjmować na wejściu dane w postaci $(\text{batch}, n)$. Natomiast na wyjściu musi zwracać wartości w postaci $(\text{batch}, 1)$ lub $(\text{batch},)$, gdzie $\text{batch}$ to liczba próbek.
#
# ### Dane
# Dane dostępne dla Ciebie w tym zadaniu to:
# * `train_dataset.csv`- plik z danymi na których będziesz trenować swój model
# * `val_dataset.csv`- plik z danymi na których przetestujesz swój model
#
# ### Kryterium Oceny
# Zadanie zostanie ocenione na podstawie metryki [MSE](https://en.wikipedia.org/wiki/Mean_squared_error) (Mean Squared Error), która jest jedną z najczęściej stosowanych metryk do oceny jakości regresji.
#
# $$MSE = \frac{1}{n} \sum_{i=1}^{n} (y_i - \hat{y}_i)^2$$
# Gdzie $y_i$ to wartość rzeczywista, a $\hat{y}_i$ to wartość przewidziana przez model. Wartość $i$ to numer próbki, a $n$ to liczba wszystkich próbek.
#
# Ta metryka jest już przez nas zaimplementowana w tym notebooku.
#
# **Ostatecznie Twoje rozwiązanie oceniane będzie na tajnym zbiorze testowym na podstawie metryki MSE.** Zbiór testowy nie różni się znacząco od zbioru walidacyjnego.
#
# - Gdy wartość MSE dla Twojego modelu będzie wynosiła 64 (lub więcej), otrzymasz 0 punktów za zadanie
# - Gdy wartość MSE dla Twojego modelu będzie wynosiła 64 (lub mniej), otrzymasz X punktów za zadanie, gdzie X jest zdefiniowane w następujący sposób:
# $$
# \text{X} = \frac{64 - MSE}{64} \times 100
# $$

# %% [markdown]
# ## Ograniczenia
# - Twoje rozwiązanie powinno zawierać model ML/DL z wyuczalnymi parametrami. Rozwiązania czysto algorytmiczne nie będą akceptowane.
# - Twoje rozwiazanie będzie testowane na Platformie Konkursowej bez dostępu do internetu oraz w środowisku z GPU.
# - Ewaluacja Twojego finalnego rozwiązania na Platformie Konkursowej nie może trwać dłużej niż 4 minut z GPU.
# - Twój model może być trenowany maksymalnie przez 4000 iteracji, co odpowiada pojedynczemu przeiterowaniu przez zmienną ```dl``` (patrz na przykładowe rozwiązanie).
# - Twój model nie może mieć więcej niż 50000 parametrów.

# %% [markdown]
# ## Uwagi i Wskazówki
# - Każdy z ciągów ma taką samą, ustaloną długość.
# - Każdy z szukanych podciągów ma długość krótszą niż długość źródłowych ciągów.
# - Rozpatrujemy trzy podciągi. Każdy z nich ma przypisaną wartość, która jest liczbą całkowitą.
# - W każdym ciągu znajduje się dowolna liczba podciągów (w tym brak jakiegokolwiek z nich).
# - Ciągi i podciągi pochodzą z alfabetu binarnego oraz są reprezentowane w postaci list.

# %% [markdown]
# ## Pliki Zgłoszeniowe
# Ten notebook uzupełniony o Twoje rozwiązanie (patrz klasa `YourModel` oraz trening modelu).

# %% [markdown]
# ## Ewaluacja
# Pamiętaj, że podczas sprawdzania flaga `FINAL_EVALUATION_MODE` zostanie ustawiona na `True`.
#
# Za to zadanie możesz zdobyć pomiędzy 0 a 100 punktów. Liczba punktów, którą zdobędziesz, będzie wyliczona na (tajnym) zbiorze testowym na Platformie Konkursowej na podstawie wyżej wspomnianego wzoru, zaokrąglona do liczby całkowitej. Jeśli Twoje rozwiązanie nie będzie spełniało powyższych kryteriów lub nie będzie wykonywać się prawidłowo, otrzymasz za zadanie 0 punktów.

# %% [markdown]
# # Kod Startowy
#
# W tej sekcji inicjalizujemy środowisko poprzez zaimportowanie potrzebnych bibliotek i funkcji. Przygotowany kod ułatwi Tobie efektywne operowanie na danych i budowanie właściwego rozwiązania.

# %%
######################### NIE ZMIENIAJ TEJ KOMÓRKI PODCZAS WYSYŁANIA ##########################

FINAL_EVALUATION_MODE = False # Podczas sprawdzania ustawimy tą flagę na True.

# %%
######################### NIE ZMIENIAJ TEJ KOMÓRKI ##########################

import os
import gdown
import pandas
import torch
import numpy as np
import torch.optim as optim
import torch.nn as nn

# %%
######################### NIE ZMIENIAJ TEJ KOMÓRKI ##########################

def seed_everything(seed: int) -> None:
    """
    Ustawia ziarno (seed) dla odtwarzalności wyników w Pythonie, NumPy oraz PyTorch.

    Funkcja ustawia ziarno dla generatorów liczb losowych Pythonie, NumPy oraz PyTorch,
    a także konfiguruje PyTorch do pracy w trybie deterministycznym.

    Parametry:
        seed (int): Wartość ziarna do ustawienia.
    """
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
######################### NIE ZMIENIAJ TEJ KOMÓRKI ##########################

seed_everything(12345)

device = 'cuda'
assert torch.cuda.is_available(), "CUDA niedostępna!"

# %% [markdown]
# ## Ładowanie Danych
# Za pomocą poniższego kodu wczytujemy dane zawierające ciągi wraz z ich wartościami.

# %%
######################### NIE ZMIENIAJ TEJ KOMÓRKI ##########################

class CSVDataloader(torch.utils.data.DataLoader):
    """
    Klasa CSVDataloader służy do ładowania danych z plików CSV i zwracania ich w batchach.

    Przyjmuje:
        csv_file (str): Ścieżka do pliku CSV.
        batch_size (int): Rozmiar batcha.
        shuffle (bool): Czy tasować dane.
    """
    def __init__(self, csv_file, batch_size=128, shuffle=True):

        class CSVDataset(torch.utils.data.Dataset):
            """
            Klasa CSVDataset służy do przechowywania danych z plików CSV jako pojedyncze próbki.
            """
            def __init__(self, csv_file: str):
                data = pandas.read_csv(csv_file).values
                self.x = torch.tensor(data[:, :-1], dtype=torch.float32)  # Features
                self.y = torch.tensor(data[:, -1], dtype=torch.float32)  # Labels

            def __len__(self) -> int:
                return len(self.x)

            def __getitem__(self, idx: int) -> tuple:
                return self.x[idx].long(), self.y[idx]

        dataset = CSVDataset(csv_file)
        self.seq_len = dataset.x.shape[1]
        super().__init__(dataset, batch_size=batch_size, shuffle=shuffle)

# %%
######################### NIE ZMIENIAJ TEJ KOMÓRKI ##########################

# Inicjalizacja treningowego zbioru danych
train_dataset_path = "train_dataset.csv"
val_dataset_path = "val_dataset.csv"

if not os.path.exists(train_dataset_path):
    url = "https://drive.google.com/uc?id=1INeYNpPA_YwojuQbMizlsFsERJ-PJX-E"
    gdown.download(url, train_dataset_path, quiet=True)

if not os.path.exists(val_dataset_path):
    url = "https://drive.google.com/uc?id=1oQcOMyDWVX0x76LOyp4TcFip1koRuodN"
    gdown.download(url, val_dataset_path, quiet=True)

dl = CSVDataloader("train_dataset.csv")
val_dl = CSVDataloader("val_dataset.csv")

# %% [markdown]
# ## Kod z Kryterium Oceniającym
#
# Kod, zbliżony do poniższego, będzie używany do oceny rozwiązania na zbiorze testowym.

# %%
######################### NIE ZMIENIAJ TEJ KOMÓRKI ##########################

def mse_criterium(
        estimations: torch.Tensor,
        answers: torch.Tensor
    ) -> torch.Tensor:
    """
    Oblicza wartość funkcji błędu średniokwadratowego (MSE) pomiędzy predykcjami a prawdziwymi wartościami.

    Parametry:
        estimations (torch.Tensor): Predykcje modelu.
        answers (torch.Tensor): Prawdziwe wartości.

    Zwraca:
        torch.Tensor: Wartość funkcji błędu średniokwadratowego.
    """
    return torch.mean((estimations.view(-1) - answers.view(-1)) ** 2)


def validate_model(
        model: torch.nn.Module,
        val_dl: torch.utils.data.DataLoader,
    ) -> float:
    """
    Waliduje model na zbiorze walidacyjnym. Zwraca uśrednioną wartość
    funkcji błędu średniokwadratowego dla wszystkich próbek.

    Parametry:
        model (torch.nn.Module): Model do oceny.
        val_dl (torch.utils.data.DataLoader): DataLoader z danymi walidacyjnymi.

    Zwraca:
        float: Uśredniona wartość funkcji błędu średniokwadr
    """
    model = model.eval().to(device)
    values = []
    for x, y in val_dl:
        x = x.to(device)
        y = y.to(device)
        y_pred = model(x)

        mse = mse_criterium(y_pred, y).cpu().item()
        values.append(mse)

    final_value = torch.tensor(values).mean().item()

    return final_value

def estimate_points(mse: float) -> int:
    """
    Funkcja wyznaczająca ilość punktów za zadanie na podstawie wartości funkcji błędu średniokwadratowego.

    Parametry:
        mse (float): Wartość funkcji błędu średniokwadratowego.

    Zwraca:
        int: Ilość punktów za zadanie (0 - 100).
    """
    points = max((100 * (64 - mse)) / 64, 0)
    return int(round(points))

# %% [markdown]
# ## Przykładowe Rozwiązanie
# Poniżej przedstawiamy uproszczone rozwiązanie, które służy jako przykład demonstrujący podstawową funkcjonalność notatnika. Może ono posłużyć jako punkt wyjścia do opracowania Twojego rozwiązania.
#
# Jako prosty przykład może posłuży rozwiązanie bazujące na wielowarstwowej sieci neuronowej (ang. Multi-layered perceptron, MLP).
# W tym wypadku, ciągi zer i jedynek traktujemy jako wejście do naszej sieci, natomiast jej wyjściem modelujemy wartość danego ciągu. Minimalizując błąd średniokwadratowy (ang. mean squared error, MSE) uczymy sieć prawidłowo oszacowywać wartość podciągu na bazie jego elementów.
#
# Poniższa ilustracja ukazuje w jaki sposób uczymy nasz model prawidłowo oceniać wartości ciągów.
#
# ![](https://live.staticflickr.com/65535/54328760659_2e9355bb07_c.jpg)

# %%
######################### NIE ZMIENIAJ TEJ KOMÓRKI ##########################

class MLP(nn.Module):
    """
    Klasa reprezentująca model sieci MLP z czterema ukrytymi warstwami.

    Parametry:
        input_length (int): Długość wejścia sieci (długość sekwencji).
    """
    def __init__(self, input_length: int):
        super(MLP, self).__init__()
        neurons_num = [256, 128, 64, 32]

        self.fc_layers = nn.Sequential(
            nn.Linear(input_length, neurons_num[0]),
            nn.ReLU(),
            nn.Linear(neurons_num[0], neurons_num[1]),
            nn.ReLU(),
            nn.Linear(neurons_num[1], neurons_num[2]),
            nn.ReLU(),
            nn.Linear(neurons_num[2], neurons_num[3]),
            nn.ReLU(),
            nn.Linear(neurons_num[3], 1),
        )

        print("Liczba parametrów:", sum(p.numel() for p in self.parameters()))

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        """
        Funkcja przyjmująca sekwencje danych i zwracająca predykcje ich wartości za pomocą sieci MLP.

        Parametry:
            x (torch.Tensor): Sekwencja danych.

        Zwraca:
            torch.Tensor: Predykcje wartości sekwencji.
        """
        x = x.float()
        x = self.fc_layers(x)
        return x

# %% [markdown]
# ### Trening Przykładowego Modelu

# %%
######################### NIE ZMIENIAJ TEJ KOMÓRKI ##########################

if not FINAL_EVALUATION_MODE:
	model = MLP(dl.seq_len).to(device)

	optimizer = optim.Adam(model.parameters(), lr=0.005)
	criterion = nn.MSELoss()

	model.train()
	for batch in iter(dl): # pojedyncze przeiterowanie dl - 4000 batchy
		inputs, targets = batch
		inputs, targets = inputs.to(device).long(), targets.to(device).float().unsqueeze(1)

		optimizer.zero_grad()
		outputs = model(inputs)

		loss = criterion(outputs, targets)
		loss.backward()
		optimizer.step()
# Out:
# Liczba parametrów: 49665

# %% [markdown]
# ### Ewaluacja Przykładowego Rozwiązania

# %%
######################### NIE ZMIENIAJ TEJ KOMÓRKI ##########################

# walidacja przykładowego rozwiązania
if not FINAL_EVALUATION_MODE:
    score = validate_model(model, val_dl)
    print(f"Błąd średniokwadratowy: {score:.2f}")
# Out:
# Błąd średniokwadratowy: 109.82

# %% [markdown]
# # Twoje Rozwiązanie
# W tej sekcji należy umieścić Twoje rozwiązanie. Wprowadzaj zmiany wyłącznie tutaj!

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class SmallGRU(nn.Module):
    def __init__(self, seq_len, hidden=32, num_layers=2):
        super().__init__()
        self.gru = nn.GRU(input_size=1, hidden_size=hidden,
                          num_layers=num_layers, batch_first=True, bidirectional=True)
        self.fc = nn.Sequential(
            nn.Linear(hidden * 2, 64),
            nn.Sigmoid(),
            nn.Linear(64, 1)
        )

    def forward(self, x):
        x = x.float().unsqueeze(-1)  # (B, seq_len, 1)
        out, _ = self.gru(x)  # (B, seq_len, 2*hidden)
        # global max pooling over time
        y, _ = torch.max(out, dim=1)
        return self.fc(y)

# %% [markdown]
# ### Trening Twojego Modelu
# Tutaj zaimplementuj trening Twojego modelu.

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Używane urządzenie: {device}")
max_k = min(12, dl.seq_len - 1)
model = SmallGRU(dl.seq_len).to(device)

print("Parametry modelu:", count_params(model))
assert count_params(model) < 50000, "Model ma za dużo parametrów!"

# Trening
import torch.optim as optim
optimizer = optim.Adam(model.parameters(), lr=0.005, weight_decay=1e-6)
criterion = nn.MSELoss()
model.train()
for batch in iter(dl):
    inputs, targets = batch
    inputs = inputs.to(device)
    targets = targets.to(device).float().unsqueeze(1)

    optimizer.zero_grad()
    outputs = model(inputs)
    print(loss)
    loss = criterion(outputs, targets)
    loss.backward()
    torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
    optimizer.step()

# Walidacja
model = model.eval()
mse = validate_model(model, val_dl)
score = estimate_points(mse)
print(f"Błąd średniokwadratowy: {mse:.2f}")
print(f"Estymowane punkty za zadanie: {score}")
# Out:
# Używane urządzenie: cuda
# Parametry modelu: 29761
# tensor(128.0787, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(1201.4275, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(1028.9335, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(978.7108, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(1232.5238, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(991.9254, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(930.4875, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(1003.0734, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(1063.6729, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(887.6162, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(843.0031, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(889.9905, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(1012.4462, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(903.9559, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(928.3934, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(932.9827, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(963.1971, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(834.7713, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(877.8024, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(985.6639, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(937.3894, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(931.1039, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(775.3431, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(802.7487, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(912.2744, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(817.2645, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(839.2739, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(783.5220, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(833.2665, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(822.2651, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(803.0507, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(774.3587, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(817.5002, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(772.9930, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(791.2896, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(827.6685, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(719.9653, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(818.4186, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(743.2872, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(738.5579, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(760.7014, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(692.5359, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(672.6699, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(752.9160, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(758.0967, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(659.4874, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(691.0554, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(626.6993, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(786.3765, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(673.4625, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(603.3326, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(672.1912, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(745.5861, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(559.7766, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(723.1428, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(633.3336, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(696.3548, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(586.1459, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(670.9868, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(677.6867, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(661.8518, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(548.2260, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(673.4911, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(652.1995, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(661.1311, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(625.4156, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(535.7371, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(611.3821, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(659.8357, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(641.1902, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(602.9238, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(639.7576, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(588.6133, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(677.4860, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(561.2809, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(622.2384, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(652.5093, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(626.4669, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(556.3579, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(580.9937, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(638.3486, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(539.0711, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(639.6844, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(594.7426, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(620.9952, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(567.7407, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(623.0479, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(593.7675, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(632.5042, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(603.9712, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(569.2838, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(618.3029, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(557.1050, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(553.7222, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(639.2841, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(537.8198, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(551.4292, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(575.7744, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(583.3873, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(637.2111, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(543.1067, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(581.3757, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(627.7647, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(560.7731, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(523.0842, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(569.4159, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(577.1039, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(552.3751, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(583.4097, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(537.4453, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(548.4120, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(657.4294, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(644.7664, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(590.6694, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(561.9299, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(589.7354, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(615.9868, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(606.8892, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(579.8313, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(582.5463, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(548.9268, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(593.7241, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(621.9261, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(564.2941, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(655.4834, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(627.9628, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(576.3411, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(619.1323, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(534.1512, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(607.4412, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(590.7198, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(667.1285, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(515.7311, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(599.7806, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(589.6880, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(541.0439, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(597.1899, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(597.5438, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(543.1443, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(614.8037, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(575.9057, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(645.9732, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(554.3782, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(620.6392, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(563.8794, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(622.5351, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(613.3317, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(563.3755, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(596.7289, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(674.3024, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(557.2980, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(616.7310, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(567.6627, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(613.5726, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(552.4844, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(632.3772, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(571.0989, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(550.3523, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(566.5157, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(651.3892, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(553.2105, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(683.5899, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(579.3025, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(563.5399, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(554.9498, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(657.3889, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(578.2194, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(602.1072, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(534.4868, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(647.4938, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(587.4085, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(607.3080, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(636.2220, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(631.4910, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(608.4733, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(576.3076, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(578.2935, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(594.0277, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor
device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(11.1287, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(7.8901, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(2.8421, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(5.2378, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(4.8090, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(5.5330, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(2.9818, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(7.4042, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.2797, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(4.4357, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(5.2335, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(11.1243, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(7.9268, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(5.9379, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(1.9150, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(1.1791, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(2.5006, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(6.9942, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(5.3943, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(11.4628, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(8.1562, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(15.1211, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(4.6759, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(25.6247, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.9431, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(9.3862, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(2.5601, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.4791, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(1.4812, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(5.4542, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(5.5314, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(1.5837, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(7.0176, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(4.0457, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.2220, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.3892, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(2.6671, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(35.6471, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(7.2335, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(19.2406, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(3.9977, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(74.4831, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.3194, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(52.7242, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(1.3506, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(1.2641, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(51.8657, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(3.3826, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(17.6312, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(18.6347, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.1464, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.1767, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(16.2813, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.1820, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.2134, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0740, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.1318, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0985, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.9975, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0601, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0438, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0446, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0399, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0292, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.9797, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0688, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0609, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.4716, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0529, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(6.1131, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0387, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0771, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0386, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0541, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0250, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0339, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0265, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0248, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0262, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0154, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0123, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0201, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0631, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0204, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0165, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0428, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0160, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0342, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0103, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0149, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0225, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(2.9187, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0137, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.7362, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0089, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0096, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0079, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(1.8734, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0101, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(16.2320, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0119, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0740, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0058, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(15.4542, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(37.1980, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(42.1968, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(42.2346, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(17.3866, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(17.4769, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(6.7380, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.5436, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.5384, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.1066, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(1.2686, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(3.2859, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0206, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0100, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0076, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0107, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0074, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0292, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.9177, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0041, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(17.9303, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.9027, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(18.1969, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.2131, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.9764, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0407, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0255, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(17.2787, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(4.4031, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0619, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0341, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.1656, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0181, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(15.8731, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0108, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0102, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0135, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0384, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0106, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.7639, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0109, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0150, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0058, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0054, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0076, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0090, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0702, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0049, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0047, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0037, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0031, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0043, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0036, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0031, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0033, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0086, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0036, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0028, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0022, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0033, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0027, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0103, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0033, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0025, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0015, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0017, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0016, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0022, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0025, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0027, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0022, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0038, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(5.3216, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0014, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0015, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0015, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0020, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0026, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(17.0576, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0019, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor(0.0015, device='cuda:0', grad_fn=<MseLossBackward0>)
# Błąd średniokwadratowy: 0.18
# Estymowane punkty za zadanie: 100

# %% [markdown]
# # Ewaluacja
#
# Uruchomienie poniższej komórki pozwoli sprawdzić, ile punktów zdobyłoby Twoje rozwiązanie na danych walidacyjnych. Przed wysłaniem upewnij się, że cały notebook wykonuje się od początku do końca bez błędów i bez konieczności ingerencji użytkownika po wybraniu opcji "Run All".

# %%
# ######################### NIE ZMIENIAJ TEJ KOMÓRKI ##########################

if not FINAL_EVALUATION_MODE:
    assert sum(p.numel() for p in model.parameters()) < 50000, "Model posiada za dużo parametrów"

    mse = validate_model(model, val_dl)
    score = estimate_points(mse)

    print(f"Błąd średniokwadratowy: {mse:.2f}")
    print(f"Estymowane punkty za zadanie: {score}")
# Out:
# Błąd średniokwadratowy: 0.18
# Estymowane punkty za zadanie: 100

# %% [markdown]
# Podczas sprawdzania model zostanie zapisany jako `your_model.pkl` i oceniony na zbiorze testowym.

# %%
######################### NIE ZMIENIAJ TEJ KOMÓRKI ##########################
your_model = model
if FINAL_EVALUATION_MODE:
    import cloudpickle

    OUTPUT_PATH = "file_output"
    FUNCTION_FILENAME = "your_model.pkl"
    FUNCTION_OUTPUT_PATH = os.path.join(OUTPUT_PATH, FUNCTION_FILENAME)

    if not os.path.exists(OUTPUT_PATH):
        os.makedirs(OUTPUT_PATH)

    your_model = your_model.eval()

    with open(FUNCTION_OUTPUT_PATH, "wb") as f:
        cloudpickle.dump(your_model, f)
